# %% [markdown]
# Paste your bibtex here in UTF-8 encoding to the input.bib, and run the following code.
#
# Note: A small number of references may still not have URLs added automatically. For these cases, please write the url manually.
#
# Author: Hakaze Cho.

# %% [markdown]
# If you have a semantics scholar api key, you can input it in the following cell.
#
# If you don't have a semantics scholar api key, you can skip. It can only **accelerate** the process for only efficiency but not accuracy.

# %%
semantics_scholar_api_key = None

# %%
# %pip install bibtexparser
# %pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: bibtexparser in ./.local/lib/python3.11/site-packages (1.4.3)
# Requirement already satisfied: pyparsing>=2.0.3 in /opt/conda/lib/python3.11/site-packages (from bibtexparser) (3.1.1)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import bibtexparser
import xml.etree.ElementTree as ET
import time
import os

# %%
import os
try:
    os.chdir(os.path.join(os.getcwd(), '/home/s2320415/Auto_Bib_Link')) # '.' if the path is to current folder
    #print(os.getcwd())
except:
    pass

# %%
with open('input.bib', 'rb') as bibtex_file:
    library = bibtexparser.load(bibtex_file)

# %%
# Arxiv Title Search
count = 0
succeed = 0
for paper in library.entries:
    count += 1
    if 'url' not in paper:
        print(f"Missing URL for {paper['ID']}, \"{paper['title']}\". Searching for URL...")
        # search for URL
        title = paper['title']
        title_replaced = title.replace(" ", "+")
        query = f"http://export.arxiv.org/api/query?search_query=ti:{title_replaced}&sortBy=relevance&max_results=50"
        response = requests.get(query)
        root = ET.fromstring(response.content)
        entrys = root.findall('{http://www.w3.org/2005/Atom}entry')
        for entry in entrys:
            link = entry.find('{http://www.w3.org/2005/Atom}link')
            titlefound = entry.find('{http://www.w3.org/2005/Atom}title')
            if link is not None:
                if title.lower() != titlefound.text.lower().replace("\n ", ""):
                    print(f"Title found for {paper['ID']} does not match: \"{titlefound.text}\", rejected.")
                else:
                    paper['url'] = link.attrib['href']
                    succeed += 1
                    print(f"Found URL for {paper['ID']}, \"{paper['title']}\": {paper['url']}, title found: \"{titlefound.text}\", accepted.")
                    break
            else:
                print(f"Could not find URL for {paper['ID']}.")
        else:
            print(f"Could not find URL for {paper['ID']}.")
    else:
        print(f"URL already exists for {paper['ID']}, \"{paper['title']}\".")
        succeed += 1
    print("\n")
print(f"Found {succeed} URLs out of {count} papers.")
# Out:
# URL already exists for abbas2024enhancing, "Enhancing in-context learning via linear probe calibration".
#
#
# URL already exists for basile-etal-2019-semeval, "{S}em{E}val-2019 Task 5: Multilingual Detection of Hate Speech Against Immigrants and Women in {T}witter".
#
#
# URL already exists for biderman2023pythia, "Pythia: A suite for analyzing large language models across training and scaling".
#
#
# URL already exists for bruneticl, "ICL-Markup: Structuring In-Context Learning using Soft-Token Tags".
#
#
# URL already exists for chen2023relation, "On the Relation between Sensitivity and Accuracy in In-Context Learning".
#
#
# URL already exists for cho2024token, "Token-based Decision Criteria Are Suboptimal in In-context Learning".
#
#
# URL already exists for collins2024context, "In-context learning with transformers: Softmax attention adapts to function lipschitzness".
#
#
# URL already exists for commitmentbank, "The commitmentbank: Investigating projection in naturally occurring discourse".
#
#
# URL already exists for dai2023can, "Why Can GPT Learn In-Context? Language Models Implicitly Perform Gradient Descent as Meta-Optimizers".
#
#
# URL already exists for dbpedia, "Dbpedia: A nucleus for a web of open data".
#
#
# URL already exists for dong2022survey, "A survey on in-context learning".
#
#
# URL already exists for ECE1, "Obtaining well calibrated probabilities using bayesian binning".
#
#
# Missing URL for falcon40b, "{Falcon-40B}: an open large language model with state-of-the-art performance". Searching for URL...
# Could not find URL for falcon40b.
#
#
# URL already exists for fei2023mitigating, "Mitigating Label Biases for In-context Learning".
#
#
# URL already exists for FP, "Good debt or bad debt: Detecting semantic orientations in economic texts".
#
#
# URL already exists for gibert2018hate, "{Hate Speech Dataset from a White Supremacy Forum}".
#
#
# URL already exists for gonen2023demystifying, "Demystifying Prompts in Language Models via Perplexity Estimation".
#
#
# URL already exists for gu2023pre, "Pre-Training to Learn in Context".
#
#
# URL already exists for han2023prototypical, "Prototypical calibration for few-shot learning of language models".
#
#
# URL already exists for han2023understanding, "Understanding In-Context Learning via Supportive Pretraining Data".
#
#
# URL already exists for hao2022structured, "Structured prompting: Scaling in-context learning to 1,000 examples".
#
#
# URL already exists for huang2023context, "In-context convergence of transformers".
#
#
# URL already exists for iyer2022opt, "Opt-iml: Scaling language model instruction meta learning through the lens of generalization".
#
#
# URL already exists for jeon2024information, "An information-theoretic analysis of in-context learning".
#
#
# URL already exists for jiang2023generative, "Generative Calibration for In-context Learning".
#
#
# URL already exists for kaplan2020scaling, "Scaling laws for neural language models".
#
#
# URL already exists for kossen2024context, "In-context learning learns label relationships but is not conventional learning".
#
#
# URL already exists for li2023finding, "Finding Support Examples for In-Context Learning".
#
#
# URL already exists for li2023unified, "Unified Demonstration Retriever for In-Context Learning".
#
#
# URL already exists for li2024language, "What Do Language Models Learn in Context? The Structured Task Hypothesis".
#
#
# URL already exists for liu2022makes, "What Makes Good In-Context Examples for GPT-3?".
#
#
# URL already exists for liu2024let, "Let's Learn Step by Step: Enhancing In-Context Learning Ability with Curriculum Learning".
#
#
# URL already exists for lu2022fantastically, "Fantastically Ordered Prompts and Where to Find Them: Overcoming Few-Shot Prompt Order Sensitivity".
#
#
# URL already exists for mavromatis2023examples, "Which examples to annotate for in-context learning? towards effective and efficient selection".
#
#
# URL already exists for min2022metaicl, "MetaICL: Learning to Learn In Context".
#
#
# URL already exists for min2022noisy, "Noisy Channel Language Model Prompting for Few-Shot Text Classification".
#
#
# URL already exists for min2022rethinking, "Rethinking the Role of Demonstrations: What Makes In-Context Learning Work?".
#
#
# URL already exists for mohammad-etal-2018-semeval, "{S}em{E}val-2018 Task 1: Affect in Tweets".
#
#
# URL already exists for MR, "Seeing Stars: Exploiting Class Relationships for Sentiment Categorization with Respect to Rating Scales".
#
#
# URL already exists for mrpc, "Automatically constructing a corpus of sentential paraphrases".
#
#
# URL already exists for olsson2022context, "In-context learning and induction heads".
#
#
# URL already exists for pan2023context, "What In-Context Learning" Learns" In-Context: Disentangling Task Recognition and Task Learning".
#
#
# URL already exists for qin2023context, "In-context learning with iterative demonstration selection".
#
#
# URL already exists for qwen, "Qwen Technical Report".
#
#
# URL already exists for qwen2, "Qwen2 Technical Report".
#
#
# URL already exists for radford2019language, "Language models are unsupervised multitask learners".
#
#
# URL already exists for RTE1, "The pascal recognising textual entailment challenge".
#
#
# URL already exists for RTE2, "The second pascal recognising textual entailment challenge".
#
#
# URL already exists for RTE3, "The third pascal recognizing textual entailment challenge".
#
#
# Missing URL for RTE5, "The Fifth PASCAL Recognizing Textual Entailment Challenge.". Searching for URL...
# Title found for RTE5 does not match: "What Knowledge is Needed to Solve the RTE5 Textual Entailment Challenge?", rejected.
# Title found for RTE5 does not match: "Learning to Compute Word Embeddings On the Fly", rejected.
# Title found for RTE5 does not match: "A Study of the Effect of Resolving Negation and Sentiment Analysis in
#   Recognizing Text Entailment for Arabic", rejected.
# Title found for RTE5 does not match: "Figurative Language in Recognizing Textual Entailment", rejected.
# Title found for RTE5 does not match: "Infusing Knowledge into the Textual Entailment Task Using Graph
#   Convolutional Networks", rejected.
# Title found for RTE5 does not match: "Entailment Graph Learning with Textual Entailment and Soft Transitivity", rejected.
# Title found for RTE5 does not match: "Natural Language Inference from Multiple Premises", rejected.
# Title found for RTE5 does not match: "Talking the Talk Does Not Entail Walking the Walk: On the Limits of
#   Large Language Models in Lexical Entailment Recognition", rejected.
# Title found for RTE5 does not match: "Enhancing Systematic Decompositional Natural Language Inference Using
#   Informal Logic", rejected.
# Title found for RTE5 does not match: "On the Importance of Delexicalization for Fact Verification", rejected.
# Title found for RTE5 does not match: "Experimenting AI Technologies for Disinformation Combat: the IDMO
#   Project", rejected.
# Title found for RTE5 does not match: "Textual Entailment Recognition with Semantic Features from Empirical
#   Text Representation", rejected.
# Title found for RTE5 does not match: "A Question-Entailment Approach to Question Answering", rejected.
# Title found for RTE5 does not match: "A Survey of Paraphrasing and Textual Entailment Methods", rejected.
# Title found for RTE5 does not match: "Performance Impact Caused by Hidden Bias of Training Data for
#   Recognizing Textual Entailment", rejected.
# Title found for RTE5 does not match: "SCENE: Self-Labeled Counterfactuals for Extrapolating to Negative
#   Examples", rejected.
# Title found for RTE5 does not match: "A Survey on Recognizing Textual Entailment as an NLP Evaluation", rejected.
# Title found for RTE5 does not match: "VLSP 2023 -- LTER: A Summary of the Challenge on Legal Textual
#   Entailment Recognition", rejected.
# Title found for RTE5 does not match: "Recognizing semantic relation in sentence pairs using Tree-RNNs and
#   Typed dependencies", rejected.
# Title found for RTE5 does not match: "Learning to Infer from Unlabeled Data: A Semi-supervised Learning
#   Approach for Robust Natural Language Inference", rejected.
# Title found for RTE5 does not match: "The Generation of Textual Entailment with NLML in an Intelligent
#   Dialogue system for Language Learning CSIEC", rejected.
# Title found for RTE5 does not match: "PropSegmEnt: A Large-Scale Corpus for Proposition-Level Segmentation and
#   Entailment Recognition", rejected.
# Title found for RTE5 does not match: "Textual Entailment for Effective Triple Validation in Object Prediction", rejected.
# Title found for RTE5 does not match: "Grounded Textual Entailment", rejected.
# Title found for RTE5 does not match: "Evaluating Paraphrastic Robustness in Textual Entailment Models", rejected.
# Title found for RTE5 does not match: "EntailE: Introducing Textual Entailment in Commonsense Knowledge Graph
#   Completion", rejected.
# Title found for RTE5 does not match: "WiCE: Real-World Entailment for Claims in Wikipedia", rejected.
# Title found for RTE5 does not match: "A Neural Network Model for Determining the Success or Failure of
#   High-tech Projects Development: A Case of Pharmaceutical industry", rejected.
# Title found for RTE5 does not match: "The Solution for the ICCV 2023 1st Scientific Figure Captioning
#   Challenge", rejected.
# Title found for RTE5 does not match: "Textual Entailment Recognizing by Theorem Proving Approach", rejected.
# Title found for RTE5 does not match: "End-Task Oriented Textual Entailment via Deep Explorations of
#   Inter-Sentence Interactions", rejected.
# Title found for RTE5 does not match: "Joint Learning of Sentence Embeddings for Relevance and Entailment", rejected.
# Title found for RTE5 does not match: "A Logic-based Approach for Recognizing Textual Entailment Supported by
#   Ontological Background Knowledge", rejected.
# Title found for RTE5 does not match: "Entailed Between the Lines: Incorporating Implication into NLI", rejected.
# Title found for RTE5 does not match: "The 5th Recognizing Families in the Wild Data Challenge: Predicting
#   Kinship from Faces", rejected.
# Title found for RTE5 does not match: "AbsPyramid: Benchmarking the Abstraction Ability of Language Models with
#   a Unified Entailment Graph", rejected.
# Title found for RTE5 does not match: "THiFLY Research at SemEval-2023 Task 7: A Multi-granularity System for
#   CTR-based Textual Entailment and Evidence Retrieval", rejected.
# Title found for RTE5 does not match: "Is "My Favorite New Movie" My Favorite Movie? Probing the Understanding
#   of Recursive Noun Phrases", rejected.
# Title found for RTE5 does not match: "Compositional Entailment Learning for Hyperbolic Vision-Language Models", rejected.
# Title found for RTE5 does not match: "Zero-shot Entailment of Leaderboards for Empirical AI Research", rejected.
# Title found for RTE5 does not match: "Generating Natural Language Inference Chains", rejected.
# Title found for RTE5 does not match: "Understanding tables with intermediate pre-training", rejected.
# Title found for RTE5 does not match: "Policy Compliance Detection via Expression Tree Inference", rejected.
# Title found for RTE5 does not match: "NewsQA: A Machine Comprehension Dataset", rejected.
# Title found for RTE5 does not match: "Textualized and Feature-based Models for Compound Multimodal Emotion
#   Recognition in the Wild", rejected.
# Title found for RTE5 does not match: "Without a 'doubt'? Unsupervised discovery of downward-entailing
#   operators", rejected.
# Title found for RTE5 does not match: "Reasoning about Entailment with Neural Attention", rejected.
# Title found for RTE5 does not match: "Max-Cosine Matching Based Neural Models for Recognizing Textual
#   Entailment", rejected.
# Title found for RTE5 does not match: "Dr.Quad at MEDIQA 2019: Towards Textual Inference and Question
#   Entailment using contextualized representations", rejected.
# Title found for RTE5 does not match: "Classifying the reported ability in clinical mobility descriptions", rejected.
# Could not find URL for RTE5.
#
#
# URL already exists for shi2024incontext, "In-Context Pretraining: Language Modeling Beyond Document Boundaries".
#
#
# URL already exists for shi2024larger, "Why Larger Language Models Do In-context Learning Differently?".
#
#
# URL already exists for srivastava2023beyond, "Beyond the Imitation Game: Quantifying and extrapolating the capabilities of language models".
#
#
# URL already exists for sst2, "Recursive Deep Models for Semantic Compositionality Over a Sentiment Treebank".
#
#
# URL already exists for su2023selective, "Selective Annotation Makes Language Models Better Few-Shot Learners".
#
#
# URL already exists for subj, "Baselines and bigrams: simple, good sentiment and topic classification".
#
#
# URL already exists for suzgun2023challenging, "Challenging BIG-Bench Tasks and Whether Chain-of-Thought Can Solve Them".
#
#
# URL already exists for touvron2023llama, "Llama 2: Open foundation and fine-tuned chat models".
#
#
# URL already exists for trec1, "Learning Question Classifiers".
#
#
# URL already exists for trec2, "Toward Semantics-Based Answer Pinpointing".
#
#
# URL already exists for van2024context, "In-Context Learning Demonstration Selection via Influence Analysis".
#
#
# URL already exists for voronov2024mind, "Mind your format: Towards consistent evaluation of in-context learning improvements".
#
#
# URL already exists for wang2019glue, "Glue: A multi-task benchmark and analysis platform for natural language understanding".
#
#
# Missing URL for wang2021gpt, "GPT-J-6B: A 6 billion parameter autoregressive language model". Searching for URL...
# Could not find URL for wang2021gpt.
#
#
# URL already exists for wang2023label, "Label Words are Anchors: An Information Flow Perspective for Understanding In-Context Learning".
#
#
# URL already exists for wei2022finetuned, "Finetuned Language Models are Zero-Shot Learners".
#
#
# URL already exists for wei2023larger, "Larger language models do in-context learning differently".
#
#
# URL already exists for wei2023symbol, "Symbol tuning improves in-context learning in language models".
#
#
# URL already exists for wies2024learnability, "The learnability of in-context learning".
#
#
# URL already exists for xu2023knn, "\$k\${NN} Prompting: Beyond-Context Learning with Calibration-Free Nearest Neighbor Inference".
#
#
# URL already exists for yoo2022ground, "Ground-Truth Labels Matter: A Deeper Look into Input-Label Demonstrations".
#
#
# URL already exists for Zhang2015CharacterlevelCN, "Character-level Convolutional Networks for Text Classification".
#
#
# URL already exists for zhang2022opt, "Opt: Open pre-trained transformer language models".
#
#
# URL already exists for zhao2021calibrate, "Calibrate before use: Improving few-shot performance of language models".
#
#
# URL already exists for zhao2024noisyicl, "NoisyICL: A Little Noise in Model Parameters Calibrates In-context Learning".
#
#
# URL already exists for zhou2024batch, "Batch Calibration: Rethinking Calibration for In-Context Learning and Prompt Engineering".
#
#
# Missing URL for guo2017calibration, "On calibration of modern neural networks". Searching for URL...
# Found URL for guo2017calibration, "On calibration of modern neural networks": http://arxiv.org/abs/1706.04599v2, title found: "On Calibration of Modern Neural Networks", accepted.
#
#
# Missing URL for naeini2015obtaining, "Obtaining well calibrated probabilities using bayesian binning". Searching for URL...
# Title found for naeini2015obtaining does not match: "Obtaining Accurate Probabilistic Causal Inference by Post-Processing
#   Calibration", rejected.
# Title found for naeini2015obtaining does not match: "Obtaining Calibrated Probabilities from Boosting", rejected.
# Title found for naeini2015obtaining does not match: "Obtaining Calibrated Probabilities with Personalized Ranking Models", rejected.
# Title found for naeini2015obtaining does not match: "Hystoc: Obtaining word confidences for fusion of end-to-end ASR systems", rejected.
# Title found for naeini2015obtaining does not match: "An Ad-Hoc Method for Obtaining chi**2 Values from Unbinned Maximum
#   Likelihood Fits", rejected.
# Title found for naeini2015obtaining does not match: "A Framework for Obtaining Accurate Posteriors of Strong Gravitational
#   Lensing Parameters with Flexible Priors and Implicit Likelihoods using
#   Density Estimation", rejected.
# Title found for naeini2015obtaining does not match: "Beyond temperature scaling: Obtaining well-calibrated multiclass
#   probabilities with Dirichlet calibration", rejected.
# Title found for naeini2015obtaining does not match: "PHOEG Helps Obtaining Extremal Graphs", rejected.
# Title found for naeini2015obtaining does not match: "Obtaining supernova directional information using the neutrino matter
#   oscillation pattern", rejected.
# Title found for naeini2015obtaining does not match: "An Optical Catalog of Galaxy Clusters Obtained from an Adaptive Matched
#   Filter Finder Applied to SDSS DR9 Data", rejected.
# Title found for naeini2015obtaining does not match: "Quantum Algorithm for Obtaining the Energy Spectrum of Molecular Systems", rejected.
# Title found for naeini2015obtaining does not match: "Charcoal obtained from cherry stones", rejected.
# Title found for naeini2015obtaining does not match: "A new approach for obtaining cosmological constraints from Type Ia
#   Supernovae using Approximate Bayesian Computation", rejected.
# Title found for naeini2015obtaining does not match: "Unsupervised Learning Technique to Obtain the Coordinates of Wi-Fi
#   Access Points", rejected.
# Title found for naeini2015obtaining does not match: "Comparison of the upper atmosphere temperature obtained by ground-based
#   and satellite instruments", rejected.
# Title found for naeini2015obtaining does not match: "Obtaining Measure Concentration from Markov Contraction", rejected.
# Title found for naeini2015obtaining does not match: "Utilizing Astrometric Orbits to Obtain Coronagraphic Images", rejected.
# Title found for naeini2015obtaining does not match: "Obtaining Communities with a Fitness Growth Process", rejected.
# Title found for naeini2015obtaining does not match: "A method and tool for combining differential or inclusive measurements
#   obtained with simultaneously constrained uncertainties", rejected.
# Title found for naeini2015obtaining does not match: "Provable Boolean Interaction Recovery from Tree Ensemble obtained via
#   Random Forests", rejected.
# Title found for naeini2015obtaining does not match: "Smarandache Type Function Obtained by Duality", rejected.
# Title found for naeini2015obtaining does not match: "Obtaining Spectra of Turbulent Velocity from Observations", rejected.
# Title found for naeini2015obtaining does not match: "Directive Emission Obtained by Coordinate Transformation", rejected.
# Title found for naeini2015obtaining does not match: "Obtaining Pseudo-inverse Solutions With MINRES", rejected.
# Title found for naeini2015obtaining does not match: "Experimentally obtaining metrics in general relativity", rejected.
# Title found for naeini2015obtaining does not match: "Three techniques for obtaining algebraic circle packings", rejected.
# Title found for naeini2015obtaining does not match: "ICON: Implicit Clothed humans Obtained from Normals", rejected.
# Title found for naeini2015obtaining does not match: "Development of digitally obtainable 10-year risk scores for depression
#   and anxiety in the general population", rejected.
# Title found for naeini2015obtaining does not match: "CyberEye: Obtaining Data from Virtual Desktop by Video", rejected.
# Title found for naeini2015obtaining does not match: "Astrometric Calibration and Estimate of the Systematic Error in WXM
#   Localizations Obtained by the Chicago Bayesian Method", rejected.
# Title found for naeini2015obtaining does not match: "An iterative procedure for general probability measures to obtain
#   I-projections onto intersections of convex sets", rejected.
# Title found for naeini2015obtaining does not match: "Characterization of measurement uncertainties using the correlations
#   between local outcomes obtained from maximally entangled pairs", rejected.
# Title found for naeini2015obtaining does not match: "SUePDF: a program to obtain quantitative pair distribution function from
#   electron diffraction data", rejected.
# Title found for naeini2015obtaining does not match: "Dynamics of large-scale solar-wind streams obtained by the double
#   superposed epoch analysis", rejected.
# Title found for naeini2015obtaining does not match: "Simulation study of the correlation ($X_{max}^μ$, $N^μ$) in view
#   of obtaining information on primary mass of the UHECRs", rejected.
# Title found for naeini2015obtaining does not match: "On the interpolation of calibration solutions obtained in radio
#   interferometry", rejected.
# Title found for naeini2015obtaining does not match: "Bayesian factor models for multivariate categorical data obtained from
#   questionnaires", rejected.
# Title found for naeini2015obtaining does not match: "Obtaining Global Galaxy Metallicities Using Emission Line EWs", rejected.
# Title found for naeini2015obtaining does not match: "Kea: a new tool to obtain stellar parameters from low to moderate
#   signal/noise and high-resolution Echelle spectra", rejected.
# Title found for naeini2015obtaining does not match: "Obtaining entangled photons from fully mixed states using beam splitters", rejected.
# Title found for naeini2015obtaining does not match: "Obtaining Maxwell's equations heuristically", rejected.
# Title found for naeini2015obtaining does not match: "On Obtaining Stable Rankings", rejected.
# Title found for naeini2015obtaining does not match: "How to obtain the redshift distribution from probabilistic redshift
#   estimates", rejected.
# Title found for naeini2015obtaining does not match: "A transport inequality on the sphere obtained by mass transport", rejected.
# Title found for naeini2015obtaining does not match: "Analytic error function and numeric inverse obtained by geometric means", rejected.
# Title found for naeini2015obtaining does not match: "Non-Hermitian expander obtained with Haar distributed unitaries", rejected.
# Title found for naeini2015obtaining does not match: "Varaha: A promising sampler for obtaining gravitational wave posteriors", rejected.
# Title found for naeini2015obtaining does not match: "Shifts of Finite Type Obtained by Forbidding a Single Pattern", rejected.
# Title found for naeini2015obtaining does not match: "Neural Collaborative Filtering Classification Model to Obtain Prediction
#   Reliabilities", rejected.
# Title found for naeini2015obtaining does not match: "Uncertainty of data obtained in SRF cavity vertical test", rejected.
# Could not find URL for naeini2015obtaining.
#
#
# Missing URL for schaeffer2024emergent, "Are emergent abilities of large language models a mirage?". Searching for URL...
# Found URL for schaeffer2024emergent, "Are emergent abilities of large language models a mirage?": http://arxiv.org/abs/2304.15004v2, title found: "Are Emergent Abilities of Large Language Models a Mirage?", accepted.
#
#
# Found 75 URLs out of 79 papers.

# %%
# Arxiv Number Search
count = 0
succeed = 0
for paper in library.entries:
    count += 1
    if 'url' not in paper:
        print(f"Missing URL for {paper['ID']}, \"{paper['title']}\". Searching for URL...")
        # search for URL
        title = paper['title']
        if 'journal' in paper:
            journal = paper['journal']
            if 'arXiv' in journal:
                arxiv_number = journal.split('arXiv:')[1].split(' ')[0]
                print(f"Arxiv number found for {paper['ID']}: {arxiv_number}.")
                paper['url'] = f"https://arxiv.org/abs/{arxiv_number}"
                print(f"Found URL for {paper['ID']}, \"{paper['title']}\": {paper['url']}, accepted.")
                succeed += 1
            else:
                print(f"Arxiv number not found for {paper['ID']}.")
        else:
            print(f"Journal not found for {paper['ID']}.")
    else:
        print(f"URL already exists for {paper['ID']}, \"{paper['title']}\".")
        succeed += 1
    print("\n")
print(f"Found {succeed} URLs out of {count} papers.")
# Out:
# URL already exists for abbas2024enhancing, "Enhancing in-context learning via linear probe calibration".
#
#
# URL already exists for basile-etal-2019-semeval, "{S}em{E}val-2019 Task 5: Multilingual Detection of Hate Speech Against Immigrants and Women in {T}witter".
#
#
# URL already exists for biderman2023pythia, "Pythia: A suite for analyzing large language models across training and scaling".
#
#
# URL already exists for bruneticl, "ICL-Markup: Structuring In-Context Learning using Soft-Token Tags".
#
#
# URL already exists for chen2023relation, "On the Relation between Sensitivity and Accuracy in In-Context Learning".
#
#
# URL already exists for cho2024token, "Token-based Decision Criteria Are Suboptimal in In-context Learning".
#
#
# URL already exists for collins2024context, "In-context learning with transformers: Softmax attention adapts to function lipschitzness".
#
#
# URL already exists for commitmentbank, "The commitmentbank: Investigating projection in naturally occurring discourse".
#
#
# URL already exists for dai2023can, "Why Can GPT Learn In-Context? Language Models Implicitly Perform Gradient Descent as Meta-Optimizers".
#
#
# URL already exists for dbpedia, "Dbpedia: A nucleus for a web of open data".
#
#
# URL already exists for dong2022survey, "A survey on in-context learning".
#
#
# URL already exists for ECE1, "Obtaining well calibrated probabilities using bayesian binning".
#
#
# Missing URL for falcon40b, "{Falcon-40B}: an open large language model with state-of-the-art performance". Searching for URL...
# Journal not found for falcon40b.
#
#
# URL already exists for fei2023mitigating, "Mitigating Label Biases for In-context Learning".
#
#
# URL already exists for FP, "Good debt or bad debt: Detecting semantic orientations in economic texts".
#
#
# URL already exists for gibert2018hate, "{Hate Speech Dataset from a White Supremacy Forum}".
#
#
# URL already exists for gonen2023demystifying, "Demystifying Prompts in Language Models via Perplexity Estimation".
#
#
# URL already exists for gu2023pre, "Pre-Training to Learn in Context".
#
#
# URL already exists for han2023prototypical, "Prototypical calibration for few-shot learning of language models".
#
#
# URL already exists for han2023understanding, "Understanding In-Context Learning via Supportive Pretraining Data".
#
#
# URL already exists for hao2022structured, "Structured prompting: Scaling in-context learning to 1,000 examples".
#
#
# URL already exists for huang2023context, "In-context convergence of transformers".
#
#
# URL already exists for iyer2022opt, "Opt-iml: Scaling language model instruction meta learning through the lens of generalization".
#
#
# URL already exists for jeon2024information, "An information-theoretic analysis of in-context learning".
#
#
# URL already exists for jiang2023generative, "Generative Calibration for In-context Learning".
#
#
# URL already exists for kaplan2020scaling, "Scaling laws for neural language models".
#
#
# URL already exists for kossen2024context, "In-context learning learns label relationships but is not conventional learning".
#
#
# URL already exists for li2023finding, "Finding Support Examples for In-Context Learning".
#
#
# URL already exists for li2023unified, "Unified Demonstration Retriever for In-Context Learning".
#
#
# URL already exists for li2024language, "What Do Language Models Learn in Context? The Structured Task Hypothesis".
#
#
# URL already exists for liu2022makes, "What Makes Good In-Context Examples for GPT-3?".
#
#
# URL already exists for liu2024let, "Let's Learn Step by Step: Enhancing In-Context Learning Ability with Curriculum Learning".
#
#
# URL already exists for lu2022fantastically, "Fantastically Ordered Prompts and Where to Find Them: Overcoming Few-Shot Prompt Order Sensitivity".
#
#
# URL already exists for mavromatis2023examples, "Which examples to annotate for in-context learning? towards effective and efficient selection".
#
#
# URL already exists for min2022metaicl, "MetaICL: Learning to Learn In Context".
#
#
# URL already exists for min2022noisy, "Noisy Channel Language Model Prompting for Few-Shot Text Classification".
#
#
# URL already exists for min2022rethinking, "Rethinking the Role of Demonstrations: What Makes In-Context Learning Work?".
#
#
# URL already exists for mohammad-etal-2018-semeval, "{S}em{E}val-2018 Task 1: Affect in Tweets".
#
#
# URL already exists for MR, "Seeing Stars: Exploiting Class Relationships for Sentiment Categorization with Respect to Rating Scales".
#
#
# URL already exists for mrpc, "Automatically constructing a corpus of sentential paraphrases".
#
#
# URL already exists for olsson2022context, "In-context learning and induction heads".
#
#
# URL already exists for pan2023context, "What In-Context Learning" Learns" In-Context: Disentangling Task Recognition and Task Learning".
#
#
# URL already exists for qin2023context, "In-context learning with iterative demonstration selection".
#
#
# URL already exists for qwen, "Qwen Technical Report".
#
#
# URL already exists for qwen2, "Qwen2 Technical Report".
#
#
# URL already exists for radford2019language, "Language models are unsupervised multitask learners".
#
#
# URL already exists for RTE1, "The pascal recognising textual entailment challenge".
#
#
# URL already exists for RTE2, "The second pascal recognising textual entailment challenge".
#
#
# URL already exists for RTE3, "The third pascal recognizing textual entailment challenge".
#
#
# Missing URL for RTE5, "The Fifth PASCAL Recognizing Textual Entailment Challenge.". Searching for URL...
# Arxiv number not found for RTE5.
#
#
# URL already exists for shi2024incontext, "In-Context Pretraining: Language Modeling Beyond Document Boundaries".
#
#
# URL already exists for shi2024larger, "Why Larger Language Models Do In-context Learning Differently?".
#
#
# URL already exists for srivastava2023beyond, "Beyond the Imitation Game: Quantifying and extrapolating the capabilities of language models".
#
#
# URL already exists for sst2, "Recursive Deep Models for Semantic Compositionality Over a Sentiment Treebank".
#
#
# URL already exists for su2023selective, "Selective Annotation Makes Language Models Better Few-Shot Learners".
#
#
# URL already exists for subj, "Baselines and bigrams: simple, good sentiment and topic classification".
#
#
# URL already exists for suzgun2023challenging, "Challenging BIG-Bench Tasks and Whether Chain-of-Thought Can Solve Them".
#
#
# URL already exists for touvron2023llama, "Llama 2: Open foundation and fine-tuned chat models".
#
#
# URL already exists for trec1, "Learning Question Classifiers".
#
#
# URL already exists for trec2, "Toward Semantics-Based Answer Pinpointing".
#
#
# URL already exists for van2024context, "In-Context Learning Demonstration Selection via Influence Analysis".
#
#
# URL already exists for voronov2024mind, "Mind your format: Towards consistent evaluation of in-context learning improvements".
#
#
# URL already exists for wang2019glue, "Glue: A multi-task benchmark and analysis platform for natural language understanding".
#
#
# Missing URL for wang2021gpt, "GPT-J-6B: A 6 billion parameter autoregressive language model". Searching for URL...
# Journal not found for wang2021gpt.
#
#
# URL already exists for wang2023label, "Label Words are Anchors: An Information Flow Perspective for Understanding In-Context Learning".
#
#
# URL already exists for wei2022finetuned, "Finetuned Language Models are Zero-Shot Learners".
#
#
# URL already exists for wei2023larger, "Larger language models do in-context learning differently".
#
#
# URL already exists for wei2023symbol, "Symbol tuning improves in-context learning in language models".
#
#
# URL already exists for wies2024learnability, "The learnability of in-context learning".
#
#
# URL already exists for xu2023knn, "\$k\${NN} Prompting: Beyond-Context Learning with Calibration-Free Nearest Neighbor Inference".
#
#
# URL already exists for yoo2022ground, "Ground-Truth Labels Matter: A Deeper Look into Input-Label Demonstrations".
#
#
# URL already exists for Zhang2015CharacterlevelCN, "Character-level Convolutional Networks for Text Classification".
#
#
# URL already exists for zhang2022opt, "Opt: Open pre-trained transformer language models".
#
#
# URL already exists for zhao2021calibrate, "Calibrate before use: Improving few-shot performance of language models".
#
#
# URL already exists for zhao2024noisyicl, "NoisyICL: A Little Noise in Model Parameters Calibrates In-context Learning".
#
#
# URL already exists for zhou2024batch, "Batch Calibration: Rethinking Calibration for In-Context Learning and Prompt Engineering".
#
#
# URL already exists for guo2017calibration, "On calibration of modern neural networks".
#
#
# Missing URL for naeini2015obtaining, "Obtaining well calibrated probabilities using bayesian binning". Searching for URL...
# Journal not found for naeini2015obtaining.
#
#
# URL already exists for schaeffer2024emergent, "Are emergent abilities of large language models a mirage?".
#
#
# Found 75 URLs out of 79 papers.

# %%
# Semantics Scholar Search
count = 0
succeed = 0

if semantics_scholar_api_key is not None:
    headers = {
        "x-api-key": semantics_scholar_api_key
    }
else:
    headers = {}

for paper in library.entries:
    count += 1
    if 'url' not in paper:
        print(f"Missing URL for {paper['ID']}, \"{paper['title']}\". Searching for URL...")
        # search for URL
        title = paper['title']
        query = f"https://api.semanticscholar.org/graph/v1/paper/search/match?query={title}"
        while True:
            time.sleep(1)
            response = requests.get(query, headers=headers)
            if response.status_code == 200 or response.status_code == 404:
                break
        if response.status_code == 404:
            print(f"Could not find URL for {paper['ID']}.\n")
            continue
        response_json = response.json()
        print(response_json)
        if response_json['data'] == []:
            print(f"Could not find URL for {paper['ID']}.\n")
            continue
        else:
            paperID = response_json['data'][0]['paperId']
            query_new = f"https://api.semanticscholar.org/graph/v1/paper/{paperID}?fields=url,openAccessPdf"
            while True:
                time.sleep(1)
                response_new = requests.get(query_new, headers=headers)
                if response_new.status_code == 200 or response_new.status_code == 404:
                    break
            if response_new.status_code == 404:
                print(f"Could not find URL for {paper['ID']}.\n")
                continue
            response_new_json = response_new.json()
            scholar_url = response_new_json['url']
            if "openAccessPdf" in response_new_json and response_new_json['openAccessPdf'] is not None:
                paper['url'] = response_new_json['openAccessPdf']['url']
                print(f"Found URL for {paper['ID']}, \"{paper['title']}\": {paper['url']}, accepted.")
            else:
                paper['url'] = scholar_url
                print(f"Found URL for {paper['ID']}, \"{paper['title']}\": {paper['url']}, accepted.")
            succeed += 1
    else:
        print(f"URL already exists for {paper['ID']}, \"{paper['title']}\".")
        succeed += 1
    print("\n")
print(f"Found {succeed} URLs out of {count} papers.")
# Out:
# URL already exists for abbas2024enhancing, "Enhancing in-context learning via linear probe calibration".
#
#
# URL already exists for basile-etal-2019-semeval, "{S}em{E}val-2019 Task 5: Multilingual Detection of Hate Speech Against Immigrants and Women in {T}witter".
#
#
# URL already exists for biderman2023pythia, "Pythia: A suite for analyzing large language models across training and scaling".
#
#
# URL already exists for bruneticl, "ICL-Markup: Structuring In-Context Learning using Soft-Token Tags".
#
#
# URL already exists for chen2023relation, "On the Relation between Sensitivity and Accuracy in In-Context Learning".
#
#
# URL already exists for cho2024token, "Token-based Decision Criteria Are Suboptimal in In-context Learning".
#
#
# URL already exists for collins2024context, "In-context learning with transformers: Softmax attention adapts to function lipschitzness".
#
#
# URL already exists for commitmentbank, "The commitmentbank: Investigating projection in naturally occurring discourse".
#
#
# URL already exists for dai2023can, "Why Can GPT Learn In-Context? Language Models Implicitly Perform Gradient Descent as Meta-Optimizers".
#
#
# URL already exists for dbpedia, "Dbpedia: A nucleus for a web of open data".
#
#
# URL already exists for dong2022survey, "A survey on in-context learning".
#
#
# URL already exists for ECE1, "Obtaining well calibrated probabilities using bayesian binning".
#
#
# Missing URL for falcon40b, "{Falcon-40B}: an open large language model with state-of-the-art performance". Searching for URL...
# Could not find URL for falcon40b.
#
# URL already exists for fei2023mitigating, "Mitigating Label Biases for In-context Learning".
#
#
# URL already exists for FP, "Good debt or bad debt: Detecting semantic orientations in economic texts".
#
#
# URL already exists for gibert2018hate, "{Hate Speech Dataset from a White Supremacy Forum}".
#
#
# URL already exists for gonen2023demystifying, "Demystifying Prompts in Language Models via Perplexity Estimation".
#
#
# URL already exists for gu2023pre, "Pre-Training to Learn in Context".
#
#
# URL already exists for han2023prototypical, "Prototypical calibration for few-shot learning of language models".
#
#
# URL already exists for han2023understanding, "Understanding In-Context Learning via Supportive Pretraining Data".
#
#
# URL already exists for hao2022structured, "Structured prompting: Scaling in-context learning to 1,000 examples".
#
#
# URL already exists for huang2023context, "In-context convergence of transformers".
#
#
# URL already exists for iyer2022opt, "Opt-iml: Scaling language model instruction meta learning through the lens of generalization".
#
#
# URL already exists for jeon2024information, "An information-theoretic analysis of in-context learning".
#
#
# URL already exists for jiang2023generative, "Generative Calibration for In-context Learning".
#
#
# URL already exists for kaplan2020scaling, "Scaling laws for neural language models".
#
#
# URL already exists for kossen2024context, "In-context learning learns label relationships but is not conventional learning".
#
#
# URL already exists for li2023finding, "Finding Support Examples for In-Context Learning".
#
#
# URL already exists for li2023unified, "Unified Demonstration Retriever for In-Context Learning".
#
#
# URL already exists for li2024language, "What Do Language Models Learn in Context? The Structured Task Hypothesis".
#
#
# URL already exists for liu2022makes, "What Makes Good In-Context Examples for GPT-3?".
#
#
# URL already exists for liu2024let, "Let's Learn Step by Step: Enhancing In-Context Learning Ability with Curriculum Learning".
#
#
# URL already exists for lu2022fantastically, "Fantastically Ordered Prompts and Where to Find Them: Overcoming Few-Shot Prompt Order Sensitivity".
#
#
# URL already exists for mavromatis2023examples, "Which examples to annotate for in-context learning? towards effective and efficient selection".
#
#
# URL already exists for min2022metaicl, "MetaICL: Learning to Learn In Context".
#
#
# URL already exists for min2022noisy, "Noisy Channel Language Model Prompting for Few-Shot Text Classification".
#
#
# URL already exists for min2022rethinking, "Rethinking the Role of Demonstrations: What Makes In-Context Learning Work?".
#
#
# URL already exists for mohammad-etal-2018-semeval, "{S}em{E}val-2018 Task 1: Affect in Tweets".
#
#
# URL already exists for MR, "Seeing Stars: Exploiting Class Relationships for Sentiment Categorization with Respect to Rating Scales".
#
#
# URL already exists for mrpc, "Automatically constructing a corpus of sentential paraphrases".
#
#
# URL already exists for olsson2022context, "In-context learning and induction heads".
#
#
# URL already exists for pan2023context, "What In-Context Learning" Learns" In-Context: Disentangling Task Recognition and Task Learning".
#
#
# URL already exists for qin2023context, "In-context learning with iterative demonstration selection".
#
#
# URL already exists for qwen, "Qwen Technical Report".
#
#
# URL already exists for qwen2, "Qwen2 Technical Report".
#
#
# URL already exists for radford2019language, "Language models are unsupervised multitask learners".
#
#
# URL already exists for RTE1, "The pascal recognising textual entailment challenge".
#
#
# URL already exists for RTE2, "The second pascal recognising textual entailment challenge".
#
#
# URL already exists for RTE3, "The third pascal recognizing textual entailment challenge".
#
#
# Missing URL for RTE5, "The Fifth PASCAL Recognizing Textual Entailment Challenge.". Searching for URL...
# Could not find URL for RTE5.
#
# URL already exists for shi2024incontext, "In-Context Pretraining: Language Modeling Beyond Document Boundaries".
#
#
# URL already exists for shi2024larger, "Why Larger Language Models Do In-context Learning Differently?".
#
#
# URL already exists for srivastava2023beyond, "Beyond the Imitation Game: Quantifying and extrapolating the capabilities of language models".
#
#
# URL already exists for sst2, "Recursive Deep Models for Semantic Compositionality Over a Sentiment Treebank".
#
#
# URL already exists for su2023selective, "Selective Annotation Makes Language Models Better Few-Shot Learners".
#
#
# URL already exists for subj, "Baselines and bigrams: simple, good sentiment and topic classification".
#
#
# URL already exists for suzgun2023challenging, "Challenging BIG-Bench Tasks and Whether Chain-of-Thought Can Solve Them".
#
#
# URL already exists for touvron2023llama, "Llama 2: Open foundation and fine-tuned chat models".
#
#
# URL already exists for trec1, "Learning Question Classifiers".
#
#
# URL already exists for trec2, "Toward Semantics-Based Answer Pinpointing".
#
#
# URL already exists for van2024context, "In-Context Learning Demonstration Selection via Influence Analysis".
#
#
# URL already exists for voronov2024mind, "Mind your format: Towards consistent evaluation of in-context learning improvements".
#
#
# URL already exists for wang2019glue, "Glue: A multi-task benchmark and analysis platform for natural language understanding".
#
#
# Missing URL for wang2021gpt, "GPT-J-6B: A 6 billion parameter autoregressive language model". Searching for URL...
# Could not find URL for wang2021gpt.
#
# URL already exists for wang2023label, "Label Words are Anchors: An Information Flow Perspective for Understanding In-Context Learning".
#
#
# URL already exists for wei2022finetuned, "Finetuned Language Models are Zero-Shot Learners".
#
#
# URL already exists for wei2023larger, "Larger language models do in-context learning differently".
#
#
# URL already exists for wei2023symbol, "Symbol tuning improves in-context learning in language models".
#
#
# URL already exists for wies2024learnability, "The learnability of in-context learning".
#
#
# URL already exists for xu2023knn, "\$k\${NN} Prompting: Beyond-Context Learning with Calibration-Free Nearest Neighbor Inference".
#
#
# URL already exists for yoo2022ground, "Ground-Truth Labels Matter: A Deeper Look into Input-Label Demonstrations".
#
#
# URL already exists for Zhang2015CharacterlevelCN, "Character-level Convolutional Networks for Text Classification".
#
#
# URL already exists for zhang2022opt, "Opt: Open pre-trained transformer language models".
#
#
# URL already exists for zhao2021calibrate, "Calibrate before use: Improving few-shot performance of language models".
#
#
# URL already exists for zhao2024noisyicl, "NoisyICL: A Little Noise in Model Parameters Calibrates In-context Learning".
#
#
# URL already exists for zhou2024batch, "Batch Calibration: Rethinking Calibration for In-Context Learning and Prompt Engineering".
#
#
# URL already exists for guo2017calibration, "On calibration of modern neural networks".
#
#
# URL already exists for naeini2015obtaining, "Obtaining well calibrated probabilities using bayesian binning".
#
#
# URL already exists for schaeffer2024emergent, "Are emergent abilities of large language models a mirage?".
#
#
# Found 76 URLs out of 79 papers.

# %%
# List the papers that are still missing URLs

for paper in library.entries:
    if 'url' not in paper:
        print(f"Missing URL for {paper['ID']}, \"{paper['title']}\". Please add manually.")
# Out:
# Missing URL for falcon40b, "{Falcon-40B}: an open large language model with state-of-the-art performance". Please add manually.
# Missing URL for RTE5, "The Fifth PASCAL Recognizing Textual Entailment Challenge.". Please add manually.
# Missing URL for wang2021gpt, "GPT-J-6B: A 6 billion parameter autoregressive language model". Please add manually.

# %%
print(f"Found {succeed} URLs out of {count} papers.")
with open('output.bib', 'w') as bibtex_file:
    bibtexparser.dump(library, bibtex_file)
print("Done. Output saved as output.bib.")
# Out:
# Found 76 URLs out of 79 papers.
# Done. Output saved as output.bib.
